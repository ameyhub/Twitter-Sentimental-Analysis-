# %%
## Package ##

from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from twitter import *
from tweepy import API
from tweepy import cursor 
import pandas as pd
import matplotlib.pyplot as plt

# %%
### Twitter API ###


ACCESS_TOKEN = ""
ACCESS_TOKEN_SECRET = ""
CONSUMER_KEY = ""
CONSUMER_SECRET = ""

# %%
# # # # TWITTER STREAMER # # # #




class streammingdata():
    
    def __init__(self):
        pass

    
    def streammingtweets(self, streamdata, name_of_data):

        listener = twitterlistener(streamdata)
        auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
        auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
        stream = Stream(auth, listener)

        # This line filter Twitter Streams to capture data by the keywords: 
        stream.filter(track=name_of_data)

# %%
# # # # TWITTER STREAM LISTENER # # # #




class twitterlistener(StreamListener):

    def __init__(self, streamdata):
        self.streamdata = streamdata

    def on_data(self, data):
        try:
            print(data)
            with open(self.streamdata, 'a') as tf:
                tf.write(data)
            return True
        except BaseException as e:
            print("Error on_data %s" % str(e))
        return True
          

    def on_error(self, status):
        print(status)

# %%
### main bloack ###



if __name__ == '__main__':
 
    name_of_data = ["coronavires", "covid-19", "narendramodi"]
    streamdata = "tweets.txt"

    twitter_streamer = streammingdata()
    twitter_streamer.streammingtweets(streamdata, name_of_data)
# Out:
# {"created_at":"Sun Apr 05 11:09:12 +0000 2020","id":1246756769323462656,"id_str":"1246756769323462656","text":"RT @Success_jr: This how these Haitians preparing for COVID-19 \ud83d\ude12 https:\/\/t.co\/dnjBOlebX5","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":2389736731,"id_str":"2389736731","name":"SisterM*","screen_name":"SisterMhaiti","location":"Quelque part sur la terre\ud83d\ude09","url":"http:\/\/Instagram.com\/sistermhaiti","description":"\"Jusqu\u2019ici, l\u2019Eternel nous a secourus! Eben-Ezer!\"","translator_type":"none","protected":false,"verified":true,"followers_count":60141,"friends_count":1361,"listed_count":24,"favourites_count":4403,"statuses_count":48971,"created_at":"Fri Mar 14 19:37:24 +0000 2014","utc_off
# ...
